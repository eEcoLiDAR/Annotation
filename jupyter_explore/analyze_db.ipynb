# %%
import pandas as pd

filepath="C:\\zsofia\\Amsterdam\\Work\\Teaching\\KZs_BiodiversityandGlobalChange\\GBIF_Data\\step2\\"

speciestable=pd.read_csv(filepath+'speciestable.csv',sep=';',encoding='latin-1')
plottable=pd.read_csv(filepath+'plottable.csv',sep=';',encoding='latin-1')
observationtable=pd.read_csv(filepath+'observationtable.csv',sep=';',encoding='latin-1')

# %%
print(plottable.dtypes)
print(observationtable.dtypes)
# Out:
# polygonID                          int64
# decimalLatitude                  float64
# decimalLongitude                 float64
# coordinateUncertaintyInMeters    float64
# footprintWKT                      object
# habitat                           object
# samplingProtocol                  object
# sampleSizeValue                  float64
# sampleSizeUnit                    object
# polyarea                         float64
# dtype: object
# polygonID                 int64
# eventID                  object
# speciesKey              float64
# year                      int64
# month                     int64
# day                       int64
# eventDate                object
# organismQuantity        float64
# organismQuantityType     object
# dtype: object

# %%
print(plottable.samplingProtocol.unique())

print(plottable.groupby('samplingProtocol')["polygonID"].nunique())
# Out:
# ['Braun/Blanquet (B,D&S)' 'Braun/Blanquet (aangepast door B,D&S)'
#  'Londo (1) volledig' 'Ordinale schaal' 'Tansley-decimaal'
#  '4de Bosstatistiek' 'Londo (decimaal)' 'Tansley' 'Procentueel'
#  'Tansley Plus' 'Barkman, Doing & Segal' 'RWS-MD schaal'
#  'Aantal indiv. (SBB)' 'Ordinale schaal (vd Maarel)' 'Presentie/Absentie'
#  'Doing' 'Braun/Blanquet' 'Sortspatronen' 'Maes schaal' 'Londo (2) verkort'
#  'IAWM-V' 'De Vries' 'RWS-RIZA schaal' 'Dijkgrasland']
# samplingProtocol
# 4de Bosstatistiek                         1532
# Aantal indiv. (SBB)                         17
# Barkman, Doing & Segal                     455
# Braun/Blanquet                              46
# Braun/Blanquet (B,D&S)                   48752
# Braun/Blanquet (aangepast door B,D&S)     7158
# De Vries                                    13
# Dijkgrasland                                 1
# Doing                                       35
# IAWM-V                                     130
# Londo (1) volledig                        7989
# Londo (2) verkort                           45
# Londo (decimaal)                            91
# Maes schaal                                  2
# Ordinale schaal                           1075
# Ordinale schaal (vd Maarel)              15858
# Presentie/Absentie                           1
# Procentueel                                205
# RWS-MD schaal                             4161
# RWS-RIZA schaal                              1
# Sortspatronen                                1
# Tansley                                  14562
# Tansley Plus                               288
# Tansley-decimaal                           100
# Name: polygonID, dtype: int64

# %%
import matplotlib.pyplot as plt

observationtable["year"].hist()
plt.xlabel("year")
plt.ylabel("frequency[count]")
plt.title("Observations per year")
plt.show()

# %%
observationup80=observationtable[(observationtable["organismQuantity"]>80)]

print(observationup80.shape)

observationup80["year"].hist()
plt.xlabel("year")
plt.ylabel("frequency[count]")
plt.title("Observations per year where organismQuantity>80")
plt.show()

# %%
plottable["habitat"].hist()
plt.xlabel("habitat")
plt.ylabel("frequency[count]")
plt.title("Habitat per plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-13d0a1131421> in <module>()
# ----> 1 plottable["habitat"].hist()
#       2 plt.xlabel("habitat")
#       3 plt.ylabel("frequency[count]")
#       4 plt.title("Habitat per plot")
#       5 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2198         values = self.dropna().values
#    2199
# -> 2200         ax.hist(values, bins=bins, **kwds)
#    2201         ax.grid(grid)
#    2202         axes = np.array([ax])
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in hist(***failed resolving arguments***)
#    6179             for xi in x:
#    6180                 if len(xi) > 0:
# -> 6181                     xmin = min(xmin, xi.min())
#    6182                     xmax = max(xmax, xi.max())
#    6183             bin_range = (xmin, xmax)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
