# %% [markdown]
# Import data

# %%
import pandas as pd

filepath="C:\\zsofia\\Amsterdam\\GitHub\\eEcoLiDAR\\Annotation\\Data\\"

header=pd.read_csv(filepath+'Phragmites_australis_header.csv',sep='\t')
species=pd.read_csv(filepath+'Phragmites_australis_species.csv',sep='\t')

print(header.dtypes)
print("-----------------")
print(species.dtypes)
# Out:
# PlotObservationID                   int64
# PlotID                              int64
# Bedekkingsschaal                   object
# Datum van opname                   object
# Lengte proefvlak (m)              float64
# Breedte proefvlak (m)             float64
# Opp. proefvlak (m²)               float64
# Bedekking totaal (%)              float64
# Bedekking boomlaag (%)            float64
# Bedekking struiklaag (%)          float64
# Bedekking kruidlaag (%)           float64
# Bedekking moslaag (%)             float64
# Hoogte (hoge) boomlaag (m)        float64
# Hoogte lage boomlaag (m)          float64
# Hoogte (hoge) struiklaag (m)      float64
# Hoogte lage struiklaag (m)        float64
# Gem. hoogte (hoge) kruidl (cm)    float64
# Gem. hoogte lage kruidl. (cm)     float64
# Maximale hoogte kruidlaag (cm)    float64
# Associa (1)                        object
# Incompleteness (1)                float64
# Longitude                         float64
# Latitude                          float64
# Location uncertainty (m)            int64
# Dataset                            object
# dtype: object
# -----------------
# PlotObservationID      int64
# Species name          object
# Layer                  int64
# Cover %              float64
# Cover code            object
# Taxon ID               int64
# dtype: object

# %%
from IPython.display import display, HTML

print(header.head(n=10))
# Out:
# Dataframe 1:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PlotObservationID</th>
#       <th>PlotID</th>
#       <th>Bedekkingsschaal</th>
#       <th>Datum van opname</th>
#       <th>Lengte proefvlak (m)</th>
#       <th>Breedte proefvlak (m)</th>
#       <th>Opp. proefvlak (m²)</th>
#       <th>Bedekking totaal (%)</th>
#       <th>Bedekking boomlaag (%)</th>
#       <th>Bedekking struiklaag (%)</th>
#       <th>...</th>
#       <th>Hoogte lage struiklaag (m)</th>
#       <th>Gem. hoogte (hoge) kruidl (cm)</th>
#       <th>Gem. hoogte lage kruidl. (cm)</th>
#       <th>Maximale hoogte kruidlaag (cm)</th>
#       <th>Associa (1)</th>
#       <th>Incompleteness (1)</th>
#       <th>Longitude</th>
#       <th>Latitude</th>
#       <th>Location uncertainty (m)</th>
#       <th>Dataset</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>192</td>
#       <td>192</td>
#       <td>Braun/Blanquet (B,D&amp;S)</td>
#       <td>2-9-1996</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>70.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>r33RG06 - RG Solanum dulcamara-Phragmites aust...</td>
#       <td>0.1</td>
#       <td>4.962352</td>
#       <td>53.262944</td>
#       <td>100</td>
#       <td>Adviesburos (1)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>196</td>
#       <td>196</td>
#       <td>Braun/Blanquet (B,D&amp;S)</td>
#       <td>7-8-1996</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>90.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>r08BB04C - Typho-Phragmitetum typicum</td>
#       <td>0.3</td>
#       <td>4.944453</td>
#       <td>53.254792</td>
#       <td>100</td>
#       <td>Adviesburos (1)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>233</td>
#       <td>233</td>
#       <td>Braun/Blanquet (B,D&amp;S)</td>
#       <td>9-9-1996</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>90.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>r08BB04C - Typho-Phragmitetum typicum</td>
#       <td>0.5</td>
#       <td>4.977287</td>
#       <td>53.268387</td>
#       <td>100</td>
#       <td>Adviesburos (1)</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>580</td>
#       <td>580</td>
#       <td>Braun/Blanquet (B,D&amp;S)</td>
#       <td>8-9-1997</td>
#       <td>5.0</td>
#       <td>5.0</td>
#       <td>25.0</td>
#       <td>95.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>r08RG05 - RG Carex acutiformis-[Phragmitetalia]</td>
#       <td>0.1</td>
#       <td>5.132136</td>
#       <td>51.912667</td>
#       <td>100</td>
#       <td>Adviesburos (1)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>596</td>
#       <td>596</td>
#       <td>Braun/Blanquet (B,D&amp;S)</td>
#       <td>9-9-1997</td>
#       <td>5.0</td>
#       <td>5.0</td>
#       <td>25.0</td>
#       <td>90.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>r08BB04C - Typho-Phragmitetum typicum</td>
#       <td>0.2</td>
#       <td>5.678962</td>
#       <td>51.519783</td>
#       <td>100</td>
#       <td>Adviesburos (1)</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>728</td>
#       <td>728</td>
#       <td>Braun/Blanquet (B,D&amp;S)</td>
#       <td>15-8-1997</td>
#       <td>3.0</td>
#       <td>3.0</td>
#       <td>9.0</td>
#       <td>99.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>r08BB04C - Typho-Phragmitetum typicum</td>
#       <td>0.2</td>
#       <td>5.969377</td>
#       <td>51.869659</td>
#       <td>10</td>
#       <td>Adviesburos (1)</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>929</td>
#       <td>929</td>
#       <td>Braun/Blanquet (B,D&amp;S)</td>
#       <td>15-8-1991</td>
#       <td>3.0</td>
#       <td>3.0</td>
#       <td>NaN</td>
#       <td>90.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>r08BB04C - Typho-Phragmitetum typicum</td>
#       <td>0.3</td>
#       <td>5.462315</td>
#       <td>51.853371</td>
#       <td>10</td>
#       <td>Adviesburos (1)</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>961</td>
#       <td>961</td>
#       <td>Braun/Blanquet (B,D&amp;S)</td>
#       <td>9-9-1991</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>NaN</td>
#       <td>99.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>r33RG06 - RG Solanum dulcamara-Phragmites aust...</td>
#       <td>NaN</td>
#       <td>5.254153</td>
#       <td>51.713910</td>
#       <td>10</td>
#       <td>Adviesburos (1)</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>964</td>
#       <td>964</td>
#       <td>Braun/Blanquet (B,D&amp;S)</td>
#       <td>9-9-1991</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>NaN</td>
#       <td>90.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>r33RG06 - RG Solanum dulcamara-Phragmites aust...</td>
#       <td>NaN</td>
#       <td>5.254300</td>
#       <td>51.713191</td>
#       <td>10</td>
#       <td>Adviesburos (1)</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>965</td>
#       <td>965</td>
#       <td>Braun/Blanquet (B,D&amp;S)</td>
#       <td>9-9-1991</td>
#       <td>2.0</td>
#       <td>2.0</td>
#       <td>NaN</td>
#       <td>99.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>r08BB04C - Typho-Phragmitetum typicum</td>
#       <td>NaN</td>
#       <td>5.254301</td>
#       <td>51.712742</td>
#       <td>10</td>
#       <td>Adviesburos (1)</td>
#     </tr>
#   </tbody>
# </table>
# <p>10 rows × 25 columns</p>
# </div>
